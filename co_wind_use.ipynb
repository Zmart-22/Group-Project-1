# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt

from api_key import api_key

# %%
#Colorado wind use
base_url = f'https://api.eia.gov/v2/electricity/electric-power-operational-data/data/?frequency=annual&data[0]=generation&facets[fueltypeid][]=WND&facets[location][]=CO&facets[sectorid][]=99&start=2015&end=2021&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key={api_key}'
response = requests.get(base_url).json()

#print results of the api request
print(json.dumps(response, indent = 4, sort_keys=True))
# Out:
# {
#     "apiVersion": "2.1.4",
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/data/",
#         "params": {
#             "api_key": "Nd3pHC22NdHm2v10pc5RLQqc67INutIaEar60IfG",
#             "data": [
#                 "generation"
#             ],
#             "end": 2021,
#             "facets": {
#                 "fueltypeid": [
#                     "WND"
#                 ],
#                 "location": [
#                     "CO"
#                 ],
#                 "sectorid": [
#                     99
#                 ]
#             },
#             "frequency": "annual",
#             "length": 5000,
#             "offset": 0,
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ],
#             "start": 2015
#         }
#     },
#     "response": {
#         "data": [
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 15125.697,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2021,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             },
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 13386.228,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2020,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             },
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 10852.37576,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2019,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             },
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 9745.15,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2018,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             },
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 9314.66295,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2017,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             },
#             {
#                 "fuelTypeDescription": "wind",
#                 "fueltypeid": "WND",
#                 "generation": 9421.204,
#                 "generation-units": "thousand megawatthours",
#                 "location": "CO",
#                 "period": 2016,
#                 "sectorDescription": "All Sectors",
#                 "sectorid": 99,
#                 "stateDescription": "Colorado"
#             }
#         ],
#         "dateFormat": "YYYY",
#         "description": "Monthly and annual electric power operations by state, sector, and energy source.\n    Source: Form EIA-923",
#         "frequency": "annual",
#         "total": 6
#     }
# }

# %%
#make some lists
energy_type = []
period = []
value = []
unit = []

# %%
#populate the lists
for item in range(len(response['response']['data'])):
    energy_type.append(response['response']['data'][item]['fuelTypeDescription'])
    period.append(response['response']['data'][item]['period'])
    value.append(response['response']['data'][item]['generation'])
    unit.append(response['response']['data'][item]['generation-units'])

# %%
#create dataframe from these lists
energy = {
    'Period':period,
    'Energy Type': energy_type,
    'Value':value,
    'Unit': unit
    
}

energy_df = pd.DataFrame(energy)

# %%
#df sorted by year
energy_df = energy_df.sort_values(by='Period', ascending=True)
energy_df = energy_df.reset_index(drop=True)
energy_df
# Out:
#    Period Energy Type        Value                    Unit
# 0    2016        wind   9421.20400  thousand megawatthours
# 1    2017        wind   9314.66295  thousand megawatthours
# 2    2018        wind   9745.15000  thousand megawatthours
# 3    2019        wind  10852.37576  thousand megawatthours
# 4    2020        wind  13386.22800  thousand megawatthours
# 5    2021        wind  15125.69700  thousand megawatthours

# %%
#a list to show all the units we are working with: total of 21
types_of_energy_types = energy_df['Energy Type'].unique()
types_of_energy_types
# Out:
# array(['wind'], dtype=object)
