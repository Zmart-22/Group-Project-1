# %%
import pandas as pd 
import json 
import requests


api_key= 'EhLybGenW3vz7jb4ocYVLOpGgceGcGrDceGIKNcE'

base_url= f'https://api.eia.gov/v2/total-energy/data/?frequency=monthly&data[0]=value&start=2016-01&end=2025-12&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key={api_key}'

response=requests.get(base_url).json()

print(json.dumps(response, indent =4, sort_keys=True))
# Out:
# {
#     "apiVersion": "2.1.4",
#     "request": {
#         "command": "/v2/total-energy/data/",
#         "params": {
#             "api_key": "EhLybGenW3vz7jb4ocYVLOpGgceGcGrDceGIKNcE",
#             "data": [
#                 "value"
#             ],
#             "end": "2025-12",
#             "frequency": "monthly",
#             "length": 5000,
#             "offset": 0,
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ],
#             "start": "2016-01"
#         }
#     },
#     "response": {
#         "data": [
#             {
#                 "msn": "D2RCAUS",
#                 "period": "2023-03",
#                 "seriesDescription": "Average Cost of Residential Heating Oil in Dollars per Million Btu",
#                 "unit": "Dollars per Million Btu",
#                 "value": "Not Available"
#             },
#             {
# ...
