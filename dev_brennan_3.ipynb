# %%
import pandas as pd 
import json 
import requests


api_key= 'EhLybGenW3vz7jb4ocYVLOpGgceGcGrDceGIKNcE'

base_url= f'https://api.eia.gov/v2/aeo/2023/data/?frequency=annual&data[0]=value&facets[tableId][]=24&start=2028&end=2028&offset=0&length=5000&api_key={api_key}'

response=requests.get(base_url).json()

print(json.dumps(response, indent =4, sort_keys=True))
# Out:
# {
#     "apiVersion": "2.1.4",
#     "request": {
#         "command": "/v2/aeo/2023/data/",
#         "params": {
#             "data": [
#                 "value"
#             ],
#             "end": 2028,
#             "facets": {
#                 "tableId": [
#                     24
#                 ]
#             },
#             "frequency": "annual",
#             "length": 5000,
#             "offset": 0,
#             "start": 2028
#         }
#     },
#     "response": {
#         "data": [
#             {
#                 "history": "PROJECTION",
#                 "period": 2028,
#                 "regionId": "0-0",
#                 "regionName": "No Regional Tables",
#                 "scenario": "highmacro",
#                 "scenarioDescription": "High Economic Growth",
#                 "seriesId": "cnsm_NA_comm_NA_slr_therm_NA_qbtu",
#                 "seriesName": "Renewable Energy : Nonmarketed Selected Use : Commercial : Solar Thermal",
# ...
