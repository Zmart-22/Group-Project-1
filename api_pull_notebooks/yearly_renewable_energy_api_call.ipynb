# %%
#import dependencies
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt

#api request from the eia

api_key = "5WecopwolfmCM4zg4P5Bm9ZVaRYIMFEjVa9KQZaT"

#from colorado, years 2016-2021
base_url = f'https://api.eia.gov/v2/total-energy/data/?api_key={api_key}&frequency=annual&data[0]=value&facets[msn][]=RECCBUS&facets[msn][]=REEIBUS&facets[msn][]=REICBUS&facets[msn][]=REPRBUS&facets[msn][]=RERCBUS&facets[msn][]=RETCBUS&start=2016&end=2021&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'



# Send the HTTP GET request to the API and retrieve the response
response = requests.get(base_url).json()

#print results of the api request
print(json.dumps(response, indent = 4, sort_keys=True))
# Out:
# {
#     "apiVersion": "2.1.4",
#     "request": {
#         "command": "/v2/total-energy/data/",
#         "params": {
#             "api_key": "5WecopwolfmCM4zg4P5Bm9ZVaRYIMFEjVa9KQZaT",
#             "data": [
#                 "value"
#             ],
#             "end": 2021,
#             "facets": {
#                 "msn": [
#                     "RECCBUS",
#                     "REEIBUS",
#                     "REICBUS",
#                     "REPRBUS",
#                     "RERCBUS",
#                     "RETCBUS"
#                 ]
#             },
#             "frequency": "annual",
#             "length": 5000,
#             "offset": 0,
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ],
#             "start": 2016
#         }
#     },
#     "response": {
#         "data": [
#             {
#                 "msn": "REICBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2384.421
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 12326.254
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 835.348
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 12163.188
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 315.566
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2021,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 7131.899
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 291.842
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11518.775
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 766.542
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11683.418
#             },
#             {
#                 "msn": "REICBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2319.814
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2020,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 6785.09
#             },
#             {
#                 "msn": "REICBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2458.597
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11627.479
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 836.414
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11468.477
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 279.296
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2019,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 6397.579
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11369.957
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 274.054
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 785.211
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11579.591
#             },
#             {
#                 "msn": "REICBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2511.319
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2018,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 6343.648
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11138.388
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 255.18
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 662.536
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 6231.717
#             },
#             {
#                 "msn": "REICBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2515.302
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2017,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 11259.503
#             },
#             {
#                 "msn": "RECCBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 242.294
#             },
#             {
#                 "msn": "REEIBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Electric Power Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 5529.156
#             },
#             {
#                 "msn": "RERCBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 645.714
#             },
#             {
#                 "msn": "REPRBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Production in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 10477.366
#             },
#             {
#                 "msn": "REICBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Consumed by the Industrial Sector in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 2522.887
#             },
#             {
#                 "msn": "RETCBUS",
#                 "period": 2016,
#                 "seriesDescription": "Total Renewable Energy Consumption in Trillion Btu",
#                 "unit": "Trillion Btu",
#                 "value": 10408.662
#             }
#         ],
#         "dateFormat": "YYYY",
#         "description": "These data represent the most recent comprehensive energy statistics integrated across all energy sources.  The data includes total energy production, consumption, stocks, and trade; energy prices; overviews of petroleum, natural gas, coal, electricity, nuclear energy, renewable energy, and carbon dioxide emissions; and data unit conversions values.  Source: https://www.eia.gov/totalenergy/data/monthly/pdf/mer_a_doc.pdf  Report:  MER (https://www.eia.gov/totalenergy/data/monthly/)",
#         "frequency": "annual",
#         "total": 36
#     }
# }

# %%
#lists to store the desired values
energy_type = []
period = []
value = []
unit = []

# %%
#populate the lists
for item in range(len(response['response']['data'])):
    energy_type.append(response['response']['data'][item]['seriesDescription'])
    period.append(response['response']['data'][item]['period'])
    value.append(response['response']['data'][item]['value'])
    unit.append(response['response']['data'][item]['unit'])

# %%
#create dataframe from these lists
energy = {
    'Period':period,
    'Energy Type': energy_type,
    'Value':value,
    'Unit': unit
    
}

energy_df = pd.DataFrame(energy)

# %%
#df sorted by year
energy_df = energy_df.sort_values(by='Period', ascending=True)
energy_df = energy_df.reset_index(drop=True)
energy_df
# Out:
#     Period                                        Energy Type      Value  \
# 0     2016  Total Renewable Energy Consumption in Trillion...  10408.662
# 1     2016  Total Renewable Energy Consumed by the Commerc...    242.294
# 2     2016  Total Renewable Energy Consumed by the Electri...   5529.156
# 3     2016  Total Renewable Energy Consumed by the Industr...   2522.887
# 4     2016  Total Renewable Energy Production in Trillion Btu  10477.366
# 5     2016  Total Renewable Energy Consumed by the Residen...    645.714
# 6     2017  Total Renewable Energy Production in Trillion Btu  11259.503
# 7     2017  Total Renewable Energy Consumed by the Industr...   2515.302
# 8     2017  Total Renewable Energy Consumed by the Electri...   6231.717
# 9     2017  Total Renewable Energy Consumed by the Commerc...    255.180
# 10    2017  Total Renewable Energy Consumption in Trillion...  11138.388
# 11    2017  Total Renewable Energy Consumed by the Residen...    662.536
# 12    2018  Total Renewable Energy Consumption in Trillion...  11369.957
# 13    2018  Total Renewable Energy Consumed by the Electri...   6343.648
# 14    2018  Total Renewable Energy Consumed by the Industr...   2511.319
# 15    2018  Total Renewable Energy Production in Trillion Btu  11579.591
# 16    2018  Total Renewable Energy Consumed by the Residen...    785.211
# 17    2018  Total Renewable Energy Consumed by the Commerc...    274.054
# 18    2019  Total Renewable Energy Consumed by the Electri...   6397.579
# 19    2019  Total Renewable Energy Consumption in Trillion...  11468.477
# 20    2019  Total Renewable Energy Consumed by the Residen...    836.414
# 21    2019  Total Renewable Energy Production in Trillion Btu  11627.479
# 22    2019  Total Renewable Energy Consumed by the Industr...   2458.597
# 23    2019  Total Renewable Energy Consumed by the Commerc...    279.296
# 24    2020  Total Renewable Energy Consumed by the Commerc...    291.842
# 25    2020  Total Renewable Energy Consumed by the Residen...    766.542
# 26    2020  Total Renewable Energy Consumption in Trillion...  11518.775
# 27    2020  Total Renewable Energy Consumed by the Industr...   2319.814
# 28    2020  Total Renewable Energy Consumed by the Electri...   6785.090
# 29    2020  Total Renewable Energy Production in Trillion Btu  11683.418
# 30    2021  Total Renewable Energy Consumed by the Electri...   7131.899
# 31    2021  Total Renewable Energy Consumed by the Commerc...    315.566
# 32    2021  Total Renewable Energy Consumption in Trillion...  12163.188
# 33    2021  Total Renewable Energy Consumed by the Residen...    835.348
# 34    2021  Total Renewable Energy Production in Trillion Btu  12326.254
# 35    2021  Total Renewable Energy Consumed by the Industr...   2384.421
#
#             Unit
# 0   Trillion Btu
# 1   Trillion Btu
# 2   Trillion Btu
# 3   Trillion Btu
# 4   Trillion Btu
# 5   Trillion Btu
# 6   Trillion Btu
# 7   Trillion Btu
# 8   Trillion Btu
# 9   Trillion Btu
# 10  Trillion Btu
# 11  Trillion Btu
# 12  Trillion Btu
# 13  Trillion Btu
# 14  Trillion Btu
# 15  Trillion Btu
# 16  Trillion Btu
# 17  Trillion Btu
# 18  Trillion Btu
# 19  Trillion Btu
# 20  Trillion Btu
# 21  Trillion Btu
# 22  Trillion Btu
# 23  Trillion Btu
# 24  Trillion Btu
# 25  Trillion Btu
# 26  Trillion Btu
# 27  Trillion Btu
# 28  Trillion Btu
# 29  Trillion Btu
# 30  Trillion Btu
# 31  Trillion Btu
# 32  Trillion Btu
# 33  Trillion Btu
# 34  Trillion Btu
# 35  Trillion Btu

# %%
#create csv file
energy_df.to_csv('total_renewable_energy.csv', index=False)
